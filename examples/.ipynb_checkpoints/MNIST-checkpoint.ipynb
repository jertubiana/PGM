# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sys
import os
import pickle
sys.path.append('PGM/')
import pandas as pd
try:
    import rbm
    import bm
except:
    print 'Compiling cy_utilities first'
    curr_dir = os.getcwd()
    os.chdir('PGM/')
    # !python setup.py build_ext --inplace
    print 'Compilation done'
    os.chdir(curr_dir)
    import rbm
    import bm

    
    
import matplotlib.pyplot as plt
# %matplotlib inline
import sys
sys.path.append('../source/')
sys.path.append('../utilities/')
from common_imports import set_num_threads
set_num_threads(2) # Set the number of cores. Must be executed before importing numpy&numba.
import numpy as np
import pickle
import rbm,utilities
import pandas as pd
import RBM_utils,MNIST_utils


    
import loadmnist
loadmnist.load_MNIST(globals(),'data/MNIST/') # data_mnist, data_mnist_test, labels_mnist, labels_mnist_test

# %% [markdown]
# # Visualize some MNIST samples

# %%
MNIST_utils.show_samples( data_mnist[100:200])
# Out:
# <PIL.Image.Image image mode=L size=298x298 at 0x111DFF150>

# %% [markdown]
# # Train a simple RBM model
# - Training
# - Compute some performance metric on test set (pseudo-likelihood)
# - Show the Markov Chains used throughout training (Persistent Contrastive Divergence, see Fischer & Igel)

# %%
RBM = rbm.RBM(n_v = 784, n_h = 100 ,visible='Bernoulli',hidden='Bernoulli') # Specifiy number of visible units, hidden units, hidden units type

RBM.fit(data_mnist,n_iter=10,batch_size=100,nchains=100,N_MC=1,N_PT=1, # Training options: mini-batch size, number of epochs over data
                         verbose = 0)

print 'Test set pseudo-likelihood %.3f'%(RBM.pseudo_likelihood(data_mnist_test).mean())

MNIST_utils.show_samples(RBM.fantasy_v) # Show the Markov chains used in the training
# Out:
# Starting epoch 1
# Starting epoch 2
# Starting epoch 3
# Starting epoch 4
# Starting epoch 5
# Starting epoch 6
# Starting epoch 7
# Starting epoch 8
# Starting epoch 9
# Starting epoch 10
# Test set pseudo-likelihood -0.099
# <PIL.Image.Image image mode=L size=298x298 at 0x10FBB4E50>

# %%
MNIST_utils.show_weights(RBM,sort='beta') # Show the weights columns for each hidden unit, sorted by their amplitude
# Out:
# <PIL.Image.Image image mode=L size=298x328 at 0x10D21BD90>

# %% [markdown]
# # Generate a Markov chain

# %%
# Generate a single markov chain:
datav,datah = RBM.gen_data(Nchains=2, # Number of independent Markov chains
                           Lchains=225, # Length of each Markov chain
                           Nthermalize=1000, # Number of thermalization steps before starting to record.
                           Nstep = 20, # Number of Markov Updates between each sample
                          reshape = False) # Returns a Nchains X Lchains X 784 tensor.

print datav.shape

MNIST_utils.show_samples(datav[0]) # The first chain
# Out:
# (2, 225, 784)
# <PIL.Image.Image image mode=L size=448x448 at 0x10FB8D550>

# %%
MNIST_utils.show_samples(datav[1]) # The second chain
# Out:
# <PIL.Image.Image image mode=L size=448x448 at 0x1118F4E10>

# %%
plt.imshow(datav_initial.reshape([28,28]))

# %% [markdown]
# # Obtaining better looking digits: More elaborate training with bigger RBM

# %%
# RBM2 = rbm.RBM(n_v = 784,n_h=400, visible='Bernoulli',hidden='ReLU+') # Better training - but slower.
# RBM2.fit(data_mnist,verbose=0,N_PT=10,n_iter=30)
# print RBM2.mav_acceptance_rates
# print RBM2.pseudo_likelihood(data_mnist).mean()

# MNIST_utils.show_samples(RBM2.fantasy_v[0]) # Show the Markov chains used in the training



RBM2 = pickle.load(open('models/RBM_MNIST.data'))


print 'Test set pseudo-likelihood %.3f'%RBM2.pseudo_likelihood(data_mnist_test).mean()

MNIST_utils.show_samples(RBM2.fantasy_v) # Show the Markov chains used in the training
# Out:
# Test set pseudo-likelihood -0.053
# <PIL.Image.Image image mode=L size=298x298 at 0x11576E590>

# %%
MNIST_utils.show_weights(RBM2,sort='beta') # Show the weights columns for each hidden unit, sorted by their amplitude
# Out:
# <PIL.Image.Image image mode=L size=298x1228 at 0x11576E090>

# %%
datav,datah = RBM2.gen_data(Nchains=2, # Number of independent Markov chains
                           Lchains=225, # Length of each Markov chain
                           Nthermalize=1000, # Number of thermalization steps before starting to record.
                           Nstep = 20, # Number of Markov Updates between each sample
                          reshape = False) # Returns a Nchains X Lchains X 784 tensor.

MNIST_utils.show_samples(datav[0]) # The first chain
# Out:
# <PIL.Image.Image image mode=L size=448x448 at 0x111C1C5D0>

# %%
MNIST_utils.show_samples(datav[1]) # The second chain
# Out:
# <PIL.Image.Image image mode=L size=448x448 at 0x111C1C690>

# %%
#### Start from given sample digit

datav_initial = data_mnist[:2]
# datav_initial = data_mnist[0][np.newaxis,:] # Caution: must provide (Nchains X Nv) matrix; not (Nv) vector. Use np.newaxis if only one initial condition.

Nchains = datav_initial.shape[0]
Lchains = 50

datav2,datah2 = RBM2.gen_data(Nthermalize=0,Nchains=Nchains,Lchains=Lchains,config_init=datav_initial,reshape=False,Nstep=20)

MNIST_utils.show_samples(datav2.reshape([Nchains*Lchains,784]),tile_shape=[Nchains,Lchains])
# Out:
# <PIL.Image.Image image mode=L size=1498x28 at 0x11A781C50>

# %%
#### 10 MC starting from the same digit.

datav_initial = np.repeat(data_mnist[0][np.newaxis,:],10,axis=0)

Nchains = datav_initial.shape[0]
Lchains = 50

datav2,datah2 = RBM2.gen_data(Nthermalize=0,Nchains=Nchains,Lchains=Lchains,config_init=datav_initial,reshape=False,Nstep=20)

## Visualize energy of trajectory.

F = RBM2.free_energy(datav2.reshape([Nchains*Lchains,784]) ).reshape([Nchains,Lchains]).T # Input must be (Ndata X Nv) matrix.

ylim = [F.min()-10,F.max()+10]

plt.plot(F); plt.ylim(ylim); plt.show()

MNIST_utils.show_samples(datav2.reshape([Nchains*Lchains,784]),tile_shape=[Nchains,Lchains])
# Out:
# <PIL.Image.Image image mode=L size=1498x298 at 0x1162C5F50>

# %%
import RBM_gen_lowT
reload(RBM_gen_lowT)

datav_low, datah_low = RBM_gen_lowT.gen_data_lowT(RBM2,beta=2,Nthermalize=0,Nchains=Nchains,Lchains=Lchains,config_init=datav_initial,reshape=False)



## Visualize energy of trajectory.

F = RBM2.free_energy(datav_low.reshape([Nchains*Lchains,784]) ).reshape([Nchains,Lchains]).T # Input must be (Ndata X Nv) matrix.

plt.plot(F); plt.ylim(ylim); plt.show()

MNIST_utils.show_samples(datav_low.reshape([Nchains*Lchains,784]),tile_shape=[Nchains,Lchains])
# Out:
# <PIL.Image.Image image mode=L size=1498x298 at 0x1162A2710>

# %%
import RBM_gen_lowT
reload(RBM_gen_lowT)


datav_low, datah_low = RBM_gen_lowT.gen_data_zeroT(RBM2,Nthermalize=0,Nchains=Nchains,Lchains=Lchains,config_init=datav_initial,reshape=False)



## Visualize energy of trajectory.

F = RBM2.free_energy(datav_low.reshape([Nchains*Lchains,784]) ).reshape([Nchains,Lchains]).T # Input must be (Ndata X Nv) matrix.

plt.plot(F); plt.ylim(ylim); plt.show()

MNIST_utils.show_samples(datav_low.reshape([Nchains*Lchains,784]),tile_shape=[Nchains,Lchains])
# Out:
# <PIL.Image.Image image mode=L size=1498x298 at 0x119935910>

# %%
from sklearn.linear_model import LogisticRegression
hidden_mnist = RBM2.mean_hiddens(data_mnist)

model = LogisticRegression(n_jobs=-1,verbose=1)
model.fit(hidden_mnist,labels_mnist)

probas = model.predict_proba(RBM2.mean_hiddens(datav[1]))

for i in range(10):
    plt.plot(probas[:,i],label='%s'%i)
plt.legend()    
plt.show()

entropy = (- probas * np.log(probas)).sum(1)
plt.plot(entropy)
plt.show()

# %%
weights =  1.0 + np.mod(labels_mnist,2) # give more weight to odd numbers
RBM = rbm.RBM(n_v = 784,n_h=100, visible='Bernoulli',hidden='Bernoulli')
RBM.fit(data_mnist,verbose=0,weights=weights)

MNIST_utils.show_samples(RBM.fantasy_v) # Show the Markov chains used in the training

# %%
BM = bm.BM(N=784,visible='Bernoulli') # Train pairwise model
BM.fit(data_mnist)
MNIST_utils.show_samples(BM.fantasy_x) # Show the Markov chains used in the training

# %%
RBM = rbm.RBM(n_v = 784,n_h=100, visible='Bernoulli',hidden='Gaussian') # Pairwise model with low rank interaction matrix
RBM.fit(data_mnist,verbose=0)

MNIST_utils.show_samples(RBM.fantasy_v) # Show the Markov chains used in the training

# %% [markdown]
# Observe that none of the pairwise model can reproduce accuractely digits, compared to model with non-linear hidden units. The BM models has high pseudo-likelihood, but bad likelihood

# %%
i = 550 # Visualize some couplings of BM on MNIST
plt.imshow(BM.layer.couplings[:,i].reshape([28,28]),vmin=-0.5,vmax=0.5,interpolation='none'); plt.colorbar(); 
plt.title('Coupling pixel %s <-> all others'%i); plt.show()
i = 650
plt.imshow(BM.layer.couplings[:,i].reshape([28,28]),vmin=-0.5,vmax=0.5,interpolation='none'); plt.colorbar(); 
plt.title('Coupling pixel %s <-> all others'%i)
plt.show()
plt.hist(BM.layer.couplings.flatten(),bins=100); plt.title('Histogram of all couplings')
